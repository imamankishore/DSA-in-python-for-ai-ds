# %% [markdown]
# ## 1. built in Data types

# %% [markdown]
# #### 1.1 Numeric types

# %%
a = 5
type(a)
# Out:
# int

# %%
a= 5.5 
type(a)
# Out:
# float

# %%
a = 3+2j
type(a)
# Out:
# complex

# %% [markdown]
# #### 1.2 Sequence Types

# %%
a = "This is a string"
type(a)
# Out:
# str

# %%
list1 = ['a','b',3]
type(list1)
# Out:
# list

# %% [markdown]
# - list is mutable

# %%
tuple1 = ('a' , 1 , 2)
type(tuple1)
# Out:
# tuple

# %% [markdown]
# - It is unmutable
# - It is the element separated by the comma , paranthesis is just for readibility

# %%
r = range(5)
type(r)
# Out:
# range

# %%
print(list(r))
# Out:
# [0, 1, 2, 3, 4]

# %%
r
# Out:
# range(0, 5)

# %% [markdown]
# #### 1.3 Set Types

# %%
s1 ={ 1,2,3,4,4}
type(s1)
# Out:
# set

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
# frozen set

s3 = frozenset({1,2})
s3
# Out:
# frozenset({1, 2})

# %% [markdown]
# - set is mutable
# - frozen set is unmutable

# %% [markdown]
# #### 1.4 Mapping types

# %%
d = {
    'Name' : 'Aman',
    'Age' : 20,
    'occupation' : 'Engineer'
}

d
# Out:
# {'Name': 'Aman', 'Age': 20, 'occupation': 'Engineer'}

# %%
type(d)
# Out:
# dict

# %% [markdown]
# #### 1.5 boolean Types

# %%
a = True
type(a)
# Out:
# bool

# %% [markdown]
# #### 1.6 None Type

# %%
a = None 
type(a)
# Out:
# NoneType
