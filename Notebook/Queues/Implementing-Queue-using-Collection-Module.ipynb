# %% [markdown]
# ## Implementing the queue using `Collections`

# %%
from collections import deque

# %%
class QueueUsingCollection:
    def __init__(self):
        self.queue = deque()

    def is_empty(self):
        return len(self.is_empty) == 


    def display(self):
        if self.is_empty():
            print('Cannot Display the empty List')
        else:
            print(self.queue)


    def enqueue(self,data):
        self.queue.append(data)
        self.display()


    def dequeue(self):
        if self.is_empty():
            print('Cannot dequeue List is empty')
            return
        dequeued = self.queue.popleft()


    def frontpeek(self):
        if self.is_empty():
            print('Empty Queue')
        else :
            return self.queue[0]


    def rearpeek(self):
        if self.is_empty():
            print('Empty Queue')
        else:
            return self.queue[-1]
# Out:
#   Cell In[3], line 6
#     return len(self.is_empty) ==
#                                  ^
# SyntaxError: invalid syntax
