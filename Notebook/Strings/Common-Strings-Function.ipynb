# %% [markdown]
# # Common String Function

# %%
str1 = 'Aman Kishore'
print(str1)
print(id(str1))
# Out:
# Aman Kishore
# 3085834071856

# %% [markdown]
# ### Lower

# %%
str2 = str1.lower()

# %%
print(str2)
print(id(str2))
# Out:
# aman kishore
# 3085834070768

# %% [markdown]
# - whenever we apply a string method since it is immuatable , so we will be getting a new string instead of old one

# %% [markdown]
# ### Strip

# %%
str2 = '           Data Science '

# %%
str2.strip()
# Out:
# 'Data Science'

# %% [markdown]
# - it delete the leading and trailing wide spaces

# %%
str4 = "###Data Science"

# %%
str4.strip('#')
# Out:
# 'Data Science'

# %%
str3 = "###Data Science####@@@!!"

# %%
str3 = "###Data Science####@@@!!"

str3.strip('!@#')
# Out:
# 'Data Science'

# %% [markdown]
# ### Replace

# %%
str1 = 'Data Science'

# %%
str1.replace('Science' , 'Analytics')
# Out:
# 'Data Analytics'

# %%
str2 = 'Data Science and Data Engineering'

# %%
str2.replace('Data' , 'data' , 1)
# Out:
# 'data Science and Data Engineering'

# %% [markdown]
# ### Split

# %%
str1[0:4]
# Out:
# 'Data'

# %%
str1.split()
# Out:
# ['Data', 'Science']

# %% [markdown]
# - by using spilt method it will give a split

# %%
str2 = 'Aman,Kishore'

str2 = str2.split(",")
str2
# Out:
# ['Aman', 'Kishore']

# %%
str2[0]
# Out:
# 'Aman'

# %%
name = 'Mr. Aman Kishore'

sal , full_name = name.split(maxsplit=1)
print(sal)
print(full_name)
# Out:
# Mr.
# Aman Kishore

# %% [markdown]
# ### join

# %%
l1 = ['My' ,'name' , 'is' ,'Aman']

" ".join(l1)
# Out:
# 'My name is Aman'

# %% [markdown]
# ### format
# - "sep".join(list)
