# %% [markdown]
# # String Manipulation

# %% [markdown]
# ## 1. Case Conversion

# %% [markdown]
# ### lower()

# %%
str1 = 'AMAN'

# %%
str1.lower()
# Out:
# 'aman'

# %% [markdown]
# ### upper()

# %%
str2= 'aman'

# %%
str2.upper()
# Out:
# 'AMAN'

# %% [markdown]
# ### Title()

# %%
str3 = 'my name is aman'

# %%
str3.title()
# Out:
# 'My Name Is Aman'

# %% [markdown]
# ### capitalize()

# %%
str4 = 'my name is aman'

# %%
str4.capitalize()
# Out:
# 'My name is aman'

# %% [markdown]
# ### Swapcase()

# %%
str5 = 'mY nAME iA aMAN'

# %%
str5.swapcase()
# Out:
# 'My Name Ia Aman'

# %% [markdown]
# ## 2. Whitespace Handling

# %% [markdown]
# ### Stripe

# %% [markdown]
# - already used

# %% [markdown]
# ## 3. Searching and Finding

# %% [markdown]
# ### Find

# %%
str1 = 'My name is Aman'

# %%
str1.find('Aman')
# Out:
# 11

# %% [markdown]
# ### index

# %%
str2 = 'My name is Aman'

# %%
str2.index('Aman')
# Out:
# 11

# %% [markdown]
# - it raises error if the substring is not found

# %% [markdown]
# ### Starts with()/ Ends with()

# %%
str1 =' My name is Aman'

# %%
str1.startswith('Aman')
# Out:
# False

# %% [markdown]
# ## 4. Validation Check

# %% [markdown]
# - isdigit()
# - isalpha()
# - isalnum()
# - islower()/isupper()
# - isspace()

# %% [markdown]
# ## 5.Spliiting and Joining

# %% [markdown]
# - split('sep')
# - join(List)

# %% [markdown]
# ## 6. Replacing

# %% [markdown]
# - replace('old' ,'new')

# %% [markdown]
# ## 7. Counting and Measuring

# %% [markdown]
# - len(str)
# - count('sub')

# %% [markdown]
# ## 8. Formatting

# %% [markdown]
# ### f-string

# %%
name = 'Aman'
age= 20


print(f'My name is {name} and I am {age} old')
# Out:
# My name is Aman and I am 20 old
