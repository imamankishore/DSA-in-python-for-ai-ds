# %% [markdown]
# # Strings in Python

# %%
str1 = 'This is a string in python'

# %%
str2 = " This is a string in double quotes"

# %%
str3 = '''This is a string in tripple quotes
it is multiline
can be written a long paragraph'''

# %%
print(str1)
print(str2)
print(str3)
# Out:
# This is a string in python
#  This is a string in double quotes
# This is a string in tripple quotes
# it is multiline
# can be written a long paragraph

# %%
print('Hi my name is "Aman"')
# Out:
# Hi my name is "Aman"

# %%
str3[0]
# Out:
# 'T'

# %% [markdown]
# # Propoperties of String

# %% [markdown]
# - Orederd Sequence

# %% [markdown]
# ### immuatble

# %%
str1 = 'aman'

print(id(str1))
# Out:
# 2161478557472

# %% [markdown]
# - location in a memory

# %% [markdown]
# ### iterable

# %%
for i in str1:
    print(i)
# Out:
# a
# m
# a
# n

# %% [markdown]
# ### concatenation

# %%
print(id(str1))

str1 = str1 + " Kishore"
print(id(str1))
# Out:
# 2161478557472
# 2161478685296

# %% [markdown]
# - address changes in the memory that means it is immuatable

# %% [markdown]
# ### slicing

# %%
str1[0:4:1]
# Out:
# 'aman'

# %% [markdown]
# ### Unicode

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
for i in str1:
    print(i , ord(i))
# Out:
# a 97
# m 109
# a 97
# n 110
#   32
# K 75
# i 105
# s 115
# h 104
# o 111
# r 114
# e 101

# %% [markdown]
# ### Repeatation

# %%
s1 = 'Data'

s1 * 3
# Out:
# 'DataDataData'
