# %%
class Node:
    def __init__ (self, data):
        self.data = data
        self.next = None

# %%
class SinglyLinkedList:
    def __init__ (self):
        self.head = None



    # To get the Length of SLL
    def get_length(self):
        length = 0
        current = self.head
        while current:
            length +=1
            current = current.next
        return length


    # To display the SLL
    def display(self):
        if self.head == None:
            print ('Empty List')
        else:
            current = self.head
            while current:
                print(current.data , end=' ')
                current = current.next
            print()


    # To insert at the begining of the SLL
    def insert_at_begining(self , value):
        node = Node(value)
        if self.head != None:
            node.next = self.head
        self.head = node
        self.display()



    # To insert at the end of SLL
    def insert_at_end(self, value):
        node = Node(value)
    
        # Case 1: Empty list
        if self.head == None:
            self.head = node
        # non empty
        else:
            current = self.head
            while current.next is not None:
                current = current.next
            current.next = node
    
        self.display()


    # To insert at middle of SLl
    def insert_in_middle(self , pos , value):
        n = self.get_length()
        if (pos <0) or (pos >n):
            print('Invalid postion')
        elif pos == 0:
            self.insert_at_begining(value)
        elif pos == n:
            self.insert_at_end(value)
        else:
            node = Node(value)
            p = self.head
            q = None
            for _ in range(pos):
                q = p
                p = p.next
            q.next = node
            node.next = p
            self.display()

# %% [markdown]
# - if not self.head ---- self.head = None , so if not None (None is a falsy value) , so not None is True
# - While current: --- since current will be None its falsy then the loop will exit automatically

# %% [markdown]
# ### Insertion in Singly Linked List at begining

# %% [markdown]
# - Case 1 - List is empty
# - Case 2 - List is not empty

# %% [markdown]
# ### Insertion at the End in Singly linked List

# %% [markdown]
# - Case 1 - List is empty
# - Case 2 - List is not empty

# %% [markdown]
#  | Expression               | Meaning            |
# | ------------------------ | ------------------ |
# | `while current:`         | Traverse all nodes |
# | `while current != None:` | Same as above      |
# | `while current.next:`    | Stop before last   |
# | `current = None`         | End of list        |

# %% [markdown]
# ### Insertion in the middle in Singly Linked list

# %% [markdown]
# - Case 1. postn = 0 , insertion at the begining
# - Case 2. postn = n , insertion at the end
# - Case 3. postn < n , invalid insertion
# - Case 4. postn <0<n , insertion at any where in the list

# %%
my_sll = SinglyLinkedList()
my_sll

# %%
my_sll.get_length()
# Out:
# 0

# %%
my_sll.display()
# Out:
# Empty List

# %%
my_sll.insert_at_begining(10)
# Out:
# 10

# %%
my_sll.get_length()
# Out:
# 1

# %%
my_sll.insert_at_begining(20)
my_sll.insert_at_begining(60)
my_sll.insert_at_begining(30)
# Out:
# 20 10
# 60 20 10
# 30 60 20 10

# %%
my_sll.get_length()
# Out:
# 4

# %%
my_sll.insert_at_end(50)
my_sll.insert_at_end(80)
# Out:
# 30 60 20 10 50
# 30 60 20 10 50 80

# %%
my_sll.insert_in_middle(4 ,45)
# Out:
# 30 60 20 10 45 50 80

# %%
my_sll.insert_at_end(70)
# Out:
# 30 60 20 10 45 50 80 70
