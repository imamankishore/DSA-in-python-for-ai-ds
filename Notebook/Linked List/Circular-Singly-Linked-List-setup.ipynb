# %% [markdown]
# # Circular Singly Linkled List (CSLL)

# %%
class Node:
    def __init__ (self,data):
        self.data = data
        self.next = None

# %%
class CricularSinglyLinkedList:
    def __init__ (self):
        self.head = None
        self.length = 0

    def is_empty(self):
        return self.head is None

    
    def display(self):
        if self.is_empty():
            print('Empty List')
        else:
            current = self.head
            while current != None :
                print(current.data , end=" ")
                current = current.next
                if current == self.head:
                    break
                print()

# %%
my_csll = CricularSinglyLinkedList()

# %%
my_csll.display()
# Out:
# Empty List
