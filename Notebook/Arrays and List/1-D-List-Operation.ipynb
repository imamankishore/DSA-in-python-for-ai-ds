# %% [markdown]
# # List

# %%
numbers = [1,2,5,9,4,3,7]
fruits = ['apple' , 'banana' , 'mango' , 'cherry']
mixed_list =  ['abc' , 5 , True , 2.0]

# %% [markdown]
# ### accessing the list

# %%
fruits[2]
# Out:
# 'mango'

# %% [markdown]
# ### traversal

# %%
for i in fruits:
    print(i , end=" ")
# Out:
# apple banana mango cherry

# %% [markdown]
# ### insertion

# %%
numbers.append(6)

# %%
numbers
# Out:
# [1, 2, 5, 9, 4, 3, 7, 6]

# %%
numbers.insert(1, 11)

# %%
numbers
# Out:
# [1, 11, 2, 5, 9, 4, 3, 7, 6]

# %% [markdown]
# ### merging

# %%
fruits
# Out:
# ['apple', 'banana', 'mango', 'cherry']

# %%
more_fruits = ['lemon' , 'strawberry']

# %%
fruits.extend(more_fruits)

# %%
fruits
# Out:
# ['apple', 'banana', 'mango', 'cherry', 'lemon', 'strawberry']

# %% [markdown]
# ### indexing

# %%
fruits.index('cherry')
# Out:
# 3

# %% [markdown]
# ### count

# %%
fruits.count('mango')
# Out:
# 1

# %% [markdown]
# ### sort

# %%
numbers.sort()

# %%
numbers             # now this list is sorted
# Out:
# [1, 2, 3, 4, 5, 6, 7, 9, 11]

# %% [markdown]
# ### Reverse

# %%
numbers.reverse()

# %%
numbers               # now this list is reversed
# Out:
# [11, 9, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# ### copy

# %%
fruits.copy()
# Out:
# ['apple', 'banana', 'mango', 'cherry', 'lemon', 'strawberry']

# %% [markdown]
# ### pop

# %%
fruits.pop(2)
# Out:
# 'mango'

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'lemon', 'strawberry']

# %% [markdown]
# ### remove

# %%
numbers.remove(6)

# %%
numbers
# Out:
# [11, 9, 7, 5, 4, 3, 2, 1]

# %% [markdown]
# ### clear

# %%
numbers.clear()

# %%
numbers
# Out:
# []

# %% [markdown]
# ### split

# %%
mixed_list[:2]
# Out:
# ['abc', 5]

# %%
mixed_list[2:]
# Out:
# [True, 2.0]
