# %% [markdown]
# ## Implementing Stacks - `Using collection Module`

# %%
from collections import deque

# %%
stacks = deque()

# %%
stacks
# Out:
# deque([])

# %%
len(stacks)
# Out:
# 0

# %%
stacks.append(20)
stacks.append(66)
stacks.append(78)

# %%
stacks
# Out:
# deque([20, 20, 66, 78])

# %%
stacks.pop()
# Out:
# 78

# %%
stacks
# Out:
# deque([20, 20, 66])

# %%
stacks[-1]
# Out:
# 66
